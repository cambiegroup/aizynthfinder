# %%
from aizynthfinder.interfaces import AiZynthApp
configfile=r"C:\Users\dario\workspace\aizynthfinder\config.yml"
app = AiZynthApp(configfile)
# Out:
# Loading expansion policy model from C:\Users\dario\workspace\aizynthfinder\aizynthfinder\tools\uspto_model.hdf5 to uspto
# Loading templates from C:\Users\dario\workspace\aizynthfinder\aizynthfinder\tools\uspto_templates.hdf5 to uspto
# Loading filter policy model from C:\Users\dario\workspace\aizynthfinder\aizynthfinder\tools\uspto_filter_model.hdf5 to uspto
# Loading stock from C:\Users\dario\workspace\aizynthfinder\aizynthfinder\tools\zinc_stock.hdf5 to zinc
# Loading stock from C:\Users\dario\workspace\aizynthfinder\alc315_sm to alc315_sm
# Text(value='', continuous_update=False, description='SMILES')
# Output(layout=Layout(border='1px solid silver', height='180px', width='50%'))
# ...
# Output(layout=Layout(border='1px solid silver', height='300px', overflow='auto', width='99%'))
# ...
# Output(layout=Layout(border='1px solid silver', width='99%'))

# %%
from IPython.display import display, HTML
for num, route in enumerate(app.finder.routes):
    display(HTML(f"<h2>Route {num+1}</h2>"))
    display(route["image"])
# Out:
# <h2>Route 1</h2>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1595x434 at 0x21B4381DF10>
# <h2>Route 2</h2>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1595x432 at 0x21B4381D280>
# <h2>Route 3</h2>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1593x498 at 0x21B4381DA00>
# <h2>Route 4</h2>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1593x493 at 0x21B4381D8B0>
# <h2>Route 5</h2>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1595x561 at 0x21B4381DE20>
# <h2>Route 6</h2>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1593x498 at 0x21B437A5A00>
# <h2>Route 7</h2>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1593x493 at 0x21B437A5940>
# <h2>Route 8</h2>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1595x561 at 0x21B437A5D90>
# <h2>Route 9</h2>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1595x504 at 0x21B4381D460>
# <h2>Route 10</h2>
# ...
